# %%
import requests
import numpy as np
import cv2
import time 
  
# printing the start time  
#print("The time of code execution begin is : ", end ="") 
#print(time.ctime()) 
# using sleep() to hault the code execution 
img_res = requests.get("http://192.168.43.72:8080/shot.jpg")
img_arr = np.array(bytearray(img_res.content), dtype = np.uint8)
img = cv2.imdecode(img_arr,-1)

    #cv2.imshow('frame', img)
cv2.imwrite('C:\\Users\\500061550\\Desktop\\original1.jpg',img) 
img = cv2.imread('original1.jpg')
y=100
x=0
h=507
w=900
crop_img = img[y:y+h, x:x+w]
cv2.imwrite('re_size.jpg',crop_img)
from PIL import Image
from PIL import ImageEnhance
def adjust_brightness(input_image, output_image, factor):
    image = Image.open(input_image)
    enhancer_object = ImageEnhance.Brightness(image)
    out = enhancer_object.enhance(factor)
    out.save(output_image)
if __name__ == '__main__':
    adjust_brightness('re_size.jpg','brightness.jpg',1.3)

def adjust_contrast(input_image, output_image, factor):
    image = Image.open(input_image)
    enhancer_object = ImageEnhance.Contrast(image)
    out = enhancer_object.enhance(factor)
    out.save(output_image)
if __name__ == '__main__':
    adjust_contrast('brightness.jpg','contrast.jpg', 1.7)

def adjust_sharpness(input_image, output_image, factor):
    image = Image.open(input_image)
    enhancer_object = ImageEnhance.Sharpness(image)
    out = enhancer_object.enhance(factor)
    out.save(output_image)
if __name__ == '__main__':
    adjust_sharpness('contrast.jpg','sharpness.jpg', 1.4)
import tensorflow
from imageai.Detection import ObjectDetection
execution_path = os.getcwd()
detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path , "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "contrast.jpg"), output_image_path=os.path.join(execution_path , "image_out.jpg"))
people=0
vehicles=0
for eachObject in detections:
    if eachObject["name"] == "person" :
        people=people+1
    elif eachObject["name"] in {"car","bicycle","motorcycle","truck"} :
        vehicles=vehicles+1
    #print(eachObject["name"] , " : " , eachObject["percentage_probability"] )
print("\n\nVehicle Count: " , vehicles)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     354         else:
# --> 355             conn.request(method, url, **httplib_request_kw)
#     356
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\http\client.py in request(self, method, url, body, headers)
#    1082         """Send a complete request to the server."""
# -> 1083         self._send_request(method, url, body, headers)
#    1084
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1127             body = body.encode('iso-8859-1')
# -> 1128         self.endheaders(body)
#    1129
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\http\client.py in endheaders(self, message_body)
#    1078             raise CannotSendHeader()
# -> 1079         self._send_output(message_body)
#    1080
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\http\client.py in _send_output(self, message_body)
#     910
# --> 911         self.send(msg)
#     912         if message_body is not None:
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\http\client.py in send(self, data)
#     853             if self.auto_open:
# --> 854                 self.connect()
#     855             else:
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\connection.py in connect(self)
#     182     def connect(self):
# --> 183         conn = self._new_conn()
#     184         self._prepare_conn(conn)
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e)
#     170
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002C70FCCF2E8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='192.168.43.72', port=8080): Max retries exceeded with url: /shot.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002C70FCCF2E8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-ba1acb3ac5f7> in <module>
#       8 #print(time.ctime())
#       9 # using sleep() to hault the code execution
# ---> 10 img_res = requests.get("http://192.168.43.72:8080/shot.jpg")
#      11 img_arr = np.array(bytearray(img_res.content), dtype = np.uint8)
#      12 img = cv2.imdecode(img_arr,-1)
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\users\500061550\appdata\local\programs\python\python35\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='192.168.43.72', port=8080): Max retries exceeded with url: /shot.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002C70FCCF2E8>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
